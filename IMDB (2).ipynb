# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup


url=['https://www.imdb.com/list/ls068082370/','https://www.imdb.com/list/ls068082370/?sort=list_order,asc&st_dt=&mode=detail&page=2','https://www.imdb.com/list/ls068082370/?sort=list_order,asc&st_dt=&mode=detail&page=3']

# %%
#send request

page=[]
soup=[]
text=[]
for i in url:
    page.append(requests.get(i))

for i in page:
    soup.append(BeautifulSoup(i.text,'html.parser'))

# %%
#read name
n=[]
name=[]

for i in soup:
    n.append(i.find_all(class_='lister-item-content'))
for i in n:
    for item in i:
        name.append(item.a.text)

#read Id


id=[]
Id=[]
for i in soup:
    id.append(i.find_all(class_='lister-item-index unbold text-primary'))
for i in id:
    for item in i:
        Id.append(item.text)        
        
#read year
year=[]
yr=[]
for i in soup:
    yr.append(i.find_all(class_='lister-item-year text-muted unbold'))
for i in yr:
    for item in i:
        year.append(item.text.replace('(','').replace(')',''))
        
#read genre

genre=[]
gn=[]
for i in soup:
    gn.append(i.find_all(class_='genre'))
for i in gn:
    for item in i:
        genre.append(item.text)
for i in range(250):
    genre[i]=genre[i][1:-12]
    
#read run_time

run_time=[]
rt=[]
for i in soup:
    rt.append(i.find_all(class_='runtime'))
for i in rt:
    for item in i:
        run_time.append(item.text)

        
#read rating

r=[]
rating=[]
rt=[]
for i in soup:
    rt.append(i.find_all(class_='ipl-rating-star__rating'))
for i in rt:
    for item in i:
        r.append(item.text)
c=0
for i in range(5750):
    if i==c:
        rating.append(r[i])
        c=c+23
        
#read description

description=[]
ds=[]
for i in soup:
    ds.append(i.find_all('p'))
for i in ds:
    ds1=[]
    for item in i:
        ds1.append(item.text)
    ds1=ds1[14:]
    c=0
    for i in range(len(ds1)):
        if i==c:
            description.append(ds1[i])
            c=c+4
for i in range(250):
    description[i]=description[i].replace('\n    ','')
    

#read directors and actors

el=[]
x=[]
director=[]
stars=[]
d=[]
s=[]
for i in soup:
    el.append(i.find_all('p', class_='text-muted text-small'))
c=0
for i in el:
    for item in i:
        if c%3==1:
            x.append(item.text)
        c=c+1
for i in range(250):
    x[i]=x[i].replace('\n','')
    d.append(x[i].split('|')[0])
    s.append(x[i].split('|')[1])
for i in range(250):
    d[i]=d[i].replace('Director:','')
    d[i]=d[i].replace('Directors:','')
    director.append(d[i])
    s[i]=s[i].replace('Star:','')
    s[i]=[i].replace('Stars:','')
    stars.append(a[i])
for i in range(250):
    director[i]=director[i].replace('    ','')
    stars[i]=stars[i].replace('     ','')
    
    
#read number of votes and gross income
import numpy as np
x=[]
el=[]
for i in soup:
    el.append(i.find_all('p'))
for i in el:
    x1=[]
    for item in i:
        x1.append(item.text)
    x1=x1[14:]
    c=2
    for i in range(len(x1)):
        if i==c:
            x.append(x1[i])
            c=c+4
for i in range(250):
    x[i]=x[i].replace('\n','')
    x[i]=x[i].replace('Votes:','')
    x[i]=x[i].replace('Gross:','')
votes=[]
gross=[]
for i in range(250):
    list1=x[i].split('| ')
    if len(list1)==1:
        votes.append(list1[0])
        gross.append(np.NaN)
    else:
        votes.append(list1[0])
        gross.append(list1[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-64a1bbc71d37> in <module>
#     113     director.append(d[i])
#     114     s[i]=s[i].replace('Star:','')
# --> 115     s[i]=[i].replace('Stars:','')
#     116     stars.append(a[i])
#     117 for i in range(250):
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
#creating dataframe

my_tuple=list(zip(Id,name,year,run_time,genre,rating,description,director,stars,votes,gross))



df=pd.DataFrame(my_tuple,columns=['Id','Name','Year_of_release','Run_time','Genre','Rating','Description','Director','Stars','Votes','Collection'])

df.to_csv('IMDB_top50.csv', index=False)

# %%
df
# Out:
#        Id                                               Name Year_of_release  \
# 0      1.                           The Shawshank Redemption            1994
# 1      2.                                      The Godfather            1972
# 2      3.                                    The Dark Knight            2008
# 3      4.                             The Godfather: Part II            1974
# 4      5.                                       Pulp Fiction            1994
# 5      6.                                   Schindler's List            1993
# 6      7.      The Lord of the Rings: The Return of the King            2003
# 7      8.                                       12 Angry Men            1957
# 8      9.                    Il buono, il brutto, il cattivo            1966
# 9     10.                                       Forrest Gump            1994
# 10    11.                                          Inception            2010
# ...
